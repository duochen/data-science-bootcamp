# %% [markdown]
# # Week 4 Guided Exercise: Student Success Analytics
#
# **Suggested time: 55-65 minutes | No answers are included**
#
# Upload all three CSV files to the Colab Files panel. Replace every `# TODO` with code. Use the hints only after trying independently.

# %% [markdown]
# ## Part A - Load and verify the tables

# %%
# TODO: Import Pandas using the standard short name.

# TODO: Load student_scores.csv as scores.

# TODO: Load student_attendance.csv as attendance.

# TODO: Load student_study_time.csv as study_time.

# TODO: Display the first five rows and shape of each table.

# TODO: Check whether attendance and study-time IDs are unique.

# %% [markdown]
# **Hints:** Use `pd.read_csv()`, `.head()`, `.shape`, and `.is_unique`.
#
# **Written check:** Explain why `student_id` repeats in the score table.

# %% [markdown]
# ## Part B - Group and aggregate

# %%
# TODO: Calculate the mean score for each subject.

# TODO: Group by subject and assessment.

# TODO: Calculate named mean, median, minimum, maximum, and unique-student count aggregations.

# TODO: Calculate the mean score for every grade and subject combination.

# TODO: Display each result.

# %% [markdown]
# **Hints:** Use `.groupby(..., as_index=False)`, `.agg()`, and named aggregation such as `new_name=("column", "mean")`.

# %% [markdown]
# ## Part C - Transform and pivot

# %%
# TODO: Add group_mean_score for every subject and assessment group using transform.

# TODO: Add difference_from_group_mean.

# TODO: Pivot scores into one row per student with subject and assessment columns.

# TODO: Flatten the multi-level columns into names such as math_pre and science_post.

# TODO: Reset the index and display the result.

# %% [markdown]
# **Hints:** Use `.transform("mean")`, `.pivot_table()`, a list comprehension for column names, and `.reset_index()`.

# %% [markdown]
# ## Part D - Concatenate and investigate joins

# %%
# TODO: Create separate Pre and Post score tables with identical columns.

# TODO: Stack them with concat and reset row labels.

# TODO: Create a student list from the pivot table.

# TODO: Inner merge the student list with attendance.

# TODO: Left merge the student list with attendance.

# TODO: Outer merge the student list with attendance and add an indicator column.

# TODO: Compare row counts and display unmatched rows.

# %% [markdown]
# **Hints:** Use `pd.concat(..., ignore_index=True)`, `.merge()`, `how=`, and `indicator=True`.
#
# **Written check:** Which student ID appears only in attendance? Why does that ID disappear from an inner merge?

# %% [markdown]
# ## Part E - Build a safe combined table

# %%
# TODO: Left merge the pivoted scores with attendance using student_id.

# TODO: Validate that the first merge is one-to-one.

# TODO: Left merge the result with study_time and validate it.

# TODO: Verify the final row count and missing values.

# TODO: Reproduce the study-time combination once using join on student_id indexes.

# %% [markdown]
# **Hints:** Use `validate="one_to_one"`, `.set_index()`, and `.join()`.
#
# **Written check:** Why should the finished table still contain 12 student rows?

# %% [markdown]
# ## Part F - Engineer features

# %%
# TODO: Create math_improvement.

# TODO: Create science_improvement.

# TODO: Create average_improvement.

# TODO: Create overall_post_score.

# TODO: Create attendance_rate as a percentage.

# TODO: Create hours_per_session.

# TODO: Round the four summary features to one decimal place.

# TODO: Create attendance categories with pd.cut.

# TODO: Flag students for review when attendance is below 90 OR overall post score is below 80.

# TODO: Map the Boolean flag to Review and On Track.

# %% [markdown]
# **Hints:** Use row-wise `.mean(axis=1)`, arithmetic, `pd.cut()`, `|`, parentheses, and `.map()`.

# %% [markdown]
# ## Part G - Final report

# %%
# TODO: Group the finished table by grade.

# TODO: Calculate student count, mean post score, mean improvement, mean attendance, and mean study hours.

# TODO: Round and display the grade report.

# TODO: Display students marked Review with the evidence columns.

# %% [markdown]
# ## Written conclusion
#
# Write 5-7 sentences containing:
#
# 1. One grade-level pattern supported by numbers.
# 2. One student-level pattern supported by numbers.
# 3. An explanation of one engineered feature.
# 4. One join-validation check you performed.
# 5. At least one limitation.
#
# Do **not** claim that attendance or study time caused higher scores.

# %% [markdown]
# ## Submission checklist
#
# - [ ] All cells run from top to bottom.
# - [ ] My final table has one row per score student.
# - [ ] I compared inner, left, and outer joins.
# - [ ] I used grouping, aggregation, pivot, concat, merge, join, and feature engineering.
# - [ ] My conclusion uses evidence and avoids causal claims.
