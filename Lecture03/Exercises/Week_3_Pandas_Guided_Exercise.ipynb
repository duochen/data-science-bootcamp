# %% [markdown]
# # Week 3 Guided Exercise: Student Performance Detective
#
# **Suggested time: 55–65 minutes | No answers are included**
#
# ## Mission
#
# Use Pandas to turn messy student-performance data into trustworthy answers.
#
# ## Rules
#
# 1. Run cells in order.
# 2. Replace each `# TODO` with your code.
# 3. Use the hints only after trying independently.
# 4. Do not change the raw `students` DataFrame; clean a copy.
# 5. Write conclusions using a claim, numerical evidence, and a limitation.

# %% [markdown]
# ## Part A — Load and inspect

# %%
# TODO: Import pandas using its standard short name.

# TODO: Import StringIO from the io module.

# The embedded CSV data is provided for you.
csv_text = """student_id,name,grade,math_pre,math_post,science_pre,science_post,study_hours,club
S01,Ava,9,78,88,82,90,4.5,Robotics
S02,Ben,10,85,91,80,89,5.0,AI Club
S03,Chloe,9,92,95,94,96,6.0,Science
S04,Diego,11,68,79,72,81,3.5,robotics
S05,Emma,10,88,,86,92,5.5,Art
S06,Finn,9,74,83,70,,4.0,AI Club
S07,Grace,11,90,94,91,95,6.5,Science
S08,Hassan,10,65,76,69,78,3.0, Robotics 
S09,Ivy,9,81,87,84,90,4.5,Art
S10,Jayden,11,77,85,75,84,five,AI Club
S10,Jayden,11,77,85,75,84,five,AI Club
S11,Kai,10,83,90,88,93,5.0,science
"""
# TODO: Read csv_text into a DataFrame named students.

# TODO: Display the first five rows.

# %% [markdown]
# **Hints:** Use `pd.read_csv(StringIO(csv_text))`, `.head()`, `.shape`, `.info()`, `.isna().sum()`, and `.duplicated().sum()`.

# %% [markdown]
# ### Task 1 — Data audit

# %%
# TODO: Print the number of rows and columns.

# TODO: Display column names and data types.

# TODO: Count missing values in every column.

# TODO: Count completely duplicated rows.

# %% [markdown]
# Record at least four problems you discover: missing values, duplicate rows, an incorrect type, inconsistent text, or another issue.

# %% [markdown]
# ## Part B — Series, selection, and filtering

# %%
# TODO: Select the math_post column as a Series named math_post_scores.

# TODO: Print the Python type of math_post_scores.

# TODO: Select name, grade, math_pre, and math_post as a DataFrame named math_view.

# TODO: Display the first five rows of math_view.

# %% [markdown]
# **Hint:** One pair of brackets returns a Series; a list of column names inside brackets returns a DataFrame.

# %% [markdown]
# ### Task 2 — Answer targeted questions

# %%
# TODO: Use .loc to show name, grade, and math_pre for students with math_pre below 80.

# TODO: Filter students who are in grade 10 AND have science_pre at least 80.

# TODO: Use .iloc to display the first 4 rows and first 5 columns.

# %% [markdown]
# **Hints:** Put each Boolean condition in parentheses and join them with `&`. Remember that `.iloc` excludes the ending position.

# %% [markdown]
# ## Part C — Sort and clean

# %%
# TODO: Sort by science_post from highest to lowest and display name and science_post.

# TODO: Make a copy named clean_students.

# TODO: Strip spaces and apply title capitalization to the club column.

# TODO: Convert study_hours to numeric and coerce invalid values to NaN.

# TODO: Remove duplicate rows.

# TODO: Fill missing math_post, science_post, and study_hours values with each column's median.

# TODO: Reset the index and discard the old index.

# TODO: Verify shape, data types, missing values, and club value counts.

# %% [markdown]
# **Hints:** Use `.sort_values()`, `.copy()`, `.str.strip()`, `.str.title()`, `pd.to_numeric(..., errors="coerce")`, `.drop_duplicates()`, `.median()`, `.fillna()`, and `.reset_index(drop=True)`.

# %% [markdown]
# ## Part D — Analyze improvement

# %%
# TODO: Create math_improvement as math_post minus math_pre.

# TODO: Create science_improvement as science_post minus science_pre.

# TODO: Create average_improvement as the row average of the two improvement columns.

# TODO: Sort from greatest to smallest average_improvement and display the evidence.

# TODO: Calculate the average post-score for math.

# TODO: Calculate the average post-score for science.

# TODO: Identify the most improved student's name and improvement value.

# %% [markdown]
# **Hints:** Use `.mean(axis=1)`, `.sort_values()`, `.mean()`, `.idxmax()`, and `.loc[row_label, column_name]`.

# %% [markdown]
# ## Part E — Final report

# %%
# TODO: Print both subject post-score averages rounded to one decimal place.

# TODO: Print the most improved student's name and value rounded to one decimal place.

# %% [markdown]
# Write 4–6 sentences below the code cell. Include: the subject with the higher post-score average, the most improved student, one additional pattern, and at least one limitation. Do not claim that study time *caused* improvement.

# %% [markdown]
# ## Reflection and submission checklist
#
# - [ ] All cells run from top to bottom without errors.
# - [ ] I preserved the raw DataFrame.
# - [ ] The cleaned DataFrame has no duplicates or missing values.
# - [ ] Every conclusion contains numerical evidence.
# - [ ] I stated a limitation.
#
# **Reflection:** Which cleaning decision had the greatest potential to change the results, and why?
