# %% [markdown]
# # Google Colab Step-by-Step Student Tutorial
#
# **Course:** AI in Data Science
#
# **Important:** Do **not** upload this tutorial notebook into Google Colab. Keep it open as your instruction guide. Open Google Colab in another browser tab, create a **brand-new notebook**, and follow the steps below by typing the code yourself.
#
# By the end, you will know how to create and use a notebook, run code, upload and read data, create charts, save files, connect Google Drive, and download your finished `.ipynb` notebook.

# %% [markdown]
# ## Step 1 — Create a New Google Colab Notebook
#
# 1. Go to **https://colab.research.google.com/**.
# 2. Sign in.
# 3. Click **File → New notebook**.
# 4. Rename it to `Week1_Colab_Practice_FirstName_LastName`.
# 5. Confirm that you can see a blank code cell.

# %% [markdown]
# ## Step 2 — Create a Text Cell
#
# Click **+ Text** and type:
#
# `# My Google Colab Practice`
#
# Under it, add your name, grade, and one thing you want to learn about AI or Data Science. A text cell uses Markdown and is for explanations, headings, and notes.

# %% [markdown]
# ## Step 3 — Run Your First Code Cell
#
# Click **+ Code**. Type and run:
#
# ```python
# print("Hello, Google Colab!")  # Print a message to confirm that Python is running.
# ```
#
# Run it with the ▶ button or **Shift + Enter**. Then create another code cell that prints your name, grade, and favorite subject. Every code line should include a plain-English comment.

# %% [markdown]
# ## Step 4 — Practice Variables
#
# Create a new code cell and type:
#
# ```python
# student_name = "Alex"  # Store a student's name as text.
# grade_level = 10  # Store the student's grade level as a whole number.
# study_hours = 6.5  # Store the number of study hours as a decimal number.
# print(student_name)  # Display the student's name.
# print(grade_level)  # Display the student's grade level.
# print(study_hours)  # Display the number of study hours.
# ```
#
# **Practice:** Create `my_name`, `my_grade`, and `my_goal`, then print them.

# %% [markdown]
# ## Step 5 — Practice Lists
#
# Create and run:
#
# ```python
# scores = [88, 95, 76, 92, 81]  # Create a list that stores five scores.
# print(scores)  # Display the whole list.
# print(scores[0])  # Display the first score because Python starts counting at 0.
# print(scores[-1])  # Display the last score in the list.
# ```
#
# **Practice:** Create `practice_scores` with three values, add one using `.append()`, print the second value, and print the list length with `len()`.

# %% [markdown]
# ## Step 6 — Practice a Loop
#
# Type:
#
# ```python
# temperatures = [72, 75, 79, 81, 77]  # Create a list of daily temperatures.
# for temperature in temperatures:  # Repeat the next line once for each temperature.
#     print(temperature)  # Display the current temperature.
# ```
#
# **Practice:** Use a loop to print the numbers 1 through 5 multiplied by 2.

# %% [markdown]
# ## Step 7 — Practice a Function
#
# Type:
#
# ```python
# def calculate_average(first_score, second_score):  # Define a function that accepts two scores.
#     average = (first_score + second_score) / 2  # Calculate the average of the two scores.
#     return average  # Send the calculated result back.
# result = calculate_average(88, 94)  # Call the function and store the returned value.
# print(result)  # Display the calculated average.
# ```
#
# **Practice:** Call the function again with two different scores.

# %% [markdown]
# ## Step 8 — Import Data Science Libraries
#
# Type:
#
# ```python
# import pandas as pd  # Import Pandas and use the short name pd.
# import matplotlib.pyplot as plt  # Import Matplotlib plotting tools and use the short name plt.
# print(pd.__version__)  # Display the installed Pandas version.
# ```
#
# If you see a version number, Pandas loaded successfully.

# %% [markdown]
# ## Step 9 — Understand the Runtime
#
# Type:
#
# ```python
# import os  # Import Python tools for working with files and folders.
# print(os.getcwd())  # Display the current working folder.
# print(os.listdir("."))  # Display files in the current working folder.
# ```
#
# A Colab runtime is temporary. Variables and uploaded files may disappear after a restart.

# %% [markdown]
# ## Step 10 — Open the Files Panel
#
# Click the **folder icon** on the left. The Files panel lets you upload, view, and download files. Find the `/content` working area.

# %% [markdown]
# ## Step 11 — Upload `student_scores.csv`
#
# Download the companion `student_scores.csv` file provided with this tutorial. In Colab, open the Files panel, click **Upload**, select `student_scores.csv`, and confirm that it appears in the file list.

# %% [markdown]
# ## Step 12 — Upload a File with Python
#
# Type:
#
# ```python
# from google.colab import files  # Import Colab's file helper for uploading files.
# uploaded_files = files.upload()  # Open a file chooser so you can select a file from your computer.
# print(uploaded_files.keys())  # Display the names of the uploaded files.
# ```
#
# Choose `student_scores.csv` when asked.

# %% [markdown]
# ## Step 13 — Read a CSV File with Pandas
#
# Type:
#
# ```python
# data = pd.read_csv("student_scores.csv")  # Read the CSV file into a Pandas DataFrame named data.
# print(data)  # Display the complete DataFrame.
# ```
#
# A DataFrame is a table with rows and columns.

# %% [markdown]
# ## Step 14 — Inspect the Dataset
#
# Type:
#
# ```python
# print(data.head())  # Display the first five rows of the dataset.
# print(data.shape)  # Display the number of rows and columns.
# print(data.columns)  # Display all column names.
# print(data.dtypes)  # Display the data type of each column.
# ```
#
# **Exercise:** In a text cell, answer how many rows and columns there are, which columns are numeric, and which column contains text.

# %% [markdown]
# ## Step 15 — Select Columns
#
# Type:
#
# ```python
# math_scores = data["math"]  # Select the math column from the DataFrame.
# science_scores = data["science"]  # Select the science column from the DataFrame.
# print(math_scores)  # Display all math scores.
# print(science_scores)  # Display all science scores.
# ```
#
# **Practice:** Select and print `study_hours`.

# %% [markdown]
# ## Step 16 — Calculate Simple Statistics
#
# Type:
#
# ```python
# average_math = data["math"].mean()  # Calculate the average math score.
# average_science = data["science"].mean()  # Calculate the average science score.
# highest_math = data["math"].max()  # Find the highest math score.
# print(average_math)  # Display the average math score.
# print(average_science)  # Display the average science score.
# print(highest_math)  # Display the highest math score.
# ```
#
# **Exercise:** Find average study hours, highest science score, and lowest math score.

# %% [markdown]
# ## Step 17 — Find the Student Who Studied the Most
#
# Type:
#
# ```python
# most_hours = data["study_hours"].max()  # Find the largest number of study hours.
# student_index = data["study_hours"].idxmax()  # Find the row index containing the largest study-hours value.
# student_name = data.loc[student_index, "student"]  # Use the row index to find the student's name.
# print(most_hours)  # Display the largest number of study hours.
# print(student_name)  # Display the student who studied the most.
# ```

# %% [markdown]
# ## Step 18 — Create New Columns
#
# Type:
#
# ```python
# data["average_score"] = (data["math"] + data["science"]) / 2  # Calculate each student's average score.
# print(data)  # Display the updated DataFrame with the new column.
# ```
#
# **Practice:** Create `total_score = math + science`.

# %% [markdown]
# ## Step 19 — Create a Bar Chart
#
# Type:
#
# ```python
# plt.bar(data["student"], data["average_score"])  # Create a bar chart using student names and average scores.
# plt.title("Average Score by Student")  # Add a title to the chart.
# plt.xlabel("Student")  # Label the horizontal axis.
# plt.ylabel("Average Score")  # Label the vertical axis.
# plt.xticks(rotation=45)  # Rotate student names so they are easier to read.
# plt.tight_layout()  # Adjust spacing so labels fit properly.
# plt.show()  # Display the finished chart.
# ```
#
# **Practice:** Create a second chart showing study hours by student.

# %% [markdown]
# ## Step 20 — Save a New CSV File
#
# Type:
#
# ```python
# data.to_csv("student_scores_with_average.csv", index=False)  # Save the updated DataFrame to a new CSV file without row numbers.
# print("File saved successfully.")  # Confirm that the new file was created.
# ```
#
# Open the Files panel and confirm that the file appears.

# %% [markdown]
# ## Step 21 — Download a Data File
#
# You can download from the Files panel, or type:
#
# ```python
# from google.colab import files  # Import Colab's file helper for downloading files.
# files.download("student_scores_with_average.csv")  # Download the processed CSV file to your computer.
# ```

# %% [markdown]
# ## Step 22 — Save and Download Your Notebook
#
# Colab usually saves your notebook to Google Drive automatically. Before submitting, use **File → Download → Download .ipynb**. Your file should look like `Week1_Colab_Practice_FirstName_LastName.ipynb`.

# %% [markdown]
# ## Step 23 — Connect Google Drive
#
# Type:
#
# ```python
# from google.colab import drive  # Import the Colab tool that connects the notebook to Google Drive.
# drive.mount("/content/drive")  # Mount Google Drive so the notebook can access files stored there.
# ```
#
# Files are usually available under `/content/drive/MyDrive/`.

# %% [markdown]
# ## Step 24 — Read a CSV from Google Drive
#
# If your file is stored at `/content/drive/MyDrive/AI_Data_Science/student_scores.csv`, type:
#
# ```python
# drive_data = pd.read_csv("/content/drive/MyDrive/AI_Data_Science/student_scores.csv")  # Read the CSV file from Google Drive.
# print(drive_data.head())  # Display the first five rows to confirm that the file was loaded.
# ```

# %% [markdown]
# ## Step 25 — Restart and Run All
#
# Before submitting, choose **Runtime → Restart session**, then **Runtime → Run all**. This checks that your notebook works from top to bottom and does not depend on cells being run in a strange order.

# %% [markdown]
# ## Step 26 — Common Errors
#
# **NameError:** Run the cell that created the variable first.
#
# **FileNotFoundError:** Check the Files panel and exact filename.
#
# **Cell keeps running:** Click Stop.
#
# **Notebook behaves strangely:** Restart the session and rerun from the top.

# %% [markdown]
# # Final Challenge
#
# Complete these in your own Colab notebook without looking at the solution first.
#
# 1. Add a text heading **Final Colab Challenge** and your name/grade.
# 2. Print `I can use Google Colab!`.
# 3. Read `student_scores.csv`.
# 4. Display the first five rows and dataset shape.
# 5. Calculate average study hours.
# 6. Find the highest science score.
# 7. Find the student who studied the most.
# 8. Create a `total_score` column.
# 9. Create a bar chart of science scores by student.
# 10. Save the result as `my_student_analysis.csv`.
# 11. Download that CSV.
# 12. Download your notebook as `.ipynb`.
# 13. Add a reflection text cell explaining what was easiest, hardest, why notebooks are useful, what happens to temporary files, and what you want to learn next.

# %% [markdown]
# # Submission Checklist
#
# - [ ] My notebook has my name.
# - [ ] It contains both text and code cells.
# - [ ] Every code line has a plain-English comment.
# - [ ] I uploaded and read `student_scores.csv`.
# - [ ] I analyzed the data and created a chart.
# - [ ] I saved and downloaded a new CSV.
# - [ ] I restarted the runtime and used **Run all**.
# - [ ] I downloaded my notebook as `.ipynb`.
